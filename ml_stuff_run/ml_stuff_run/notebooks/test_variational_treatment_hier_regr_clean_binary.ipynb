# %%
import python_utils.python_utils.caching as caching
import ml_stuff_run.ml_stuff_run.constants as constants
caching.init(constants.cache_folder, constants.which_hash)
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import display_pretty, display_html
import python_utils.python_utils.basic as basic
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.colors as mpl_colors
import matplotlib.cm as cm
import pdb
import numpy as np
import scipy
import ml_stuff.ml_stuff.hier_variational_regr as hvr
import causal_frl.causal_frl.hier_treatment_variational_regr as hvr
# Out:
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: mvtnorm
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: Matrix
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: stats4
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: gmm
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: sandwich
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %%
# random seed
np.random.seed(41)

# %%
# define params for simulating (x_ns, T_ns)
N = 5000
T_prob = 0.5
#K = 25
K=4
x_prob = 0.5

# %%
# simulate (x_ns, T_ns)
#x_ns = np.random.multivariate_normal(np.zeros(K), np.eye(K) * x_var, N)
x_ns = (np.random.uniform(size=(N,K)) < x_prob).astype(int)
T_ns = np.random.randint(0, 2, N)

# %%
# define rule_fs
print hvr
all_rule_fs = [hvr.binary_rule(k,1) for k in xrange(K)]
#rule_fs = [hvr.binary_rule(k,1) for k in xrange(K)] + [hvr.binary_rule(k,0) for k in xrange(K)]
print rule_fs
#rule_fs = [hvr.mem_address_rule(k,K) for k in xrange(K)]
# Out:
# <module 'causal_frl.causal_frl.hier_treatment_variational_regr' from '/Users/fultonw/Documents/projects/code/causal_frl/causal_frl/hier_treatment_variational_regr.py'>
# [bin0_1, bin1_1, bin2_1, bin3_1]

# %%
# define p_y_ns_given_theta, theta
true_rule_f_ls = all_rule_fs[0:3] + [hvr.default_rule()]
#true_rule_f_ls = rule_fs[0:10:2] + [hvr.default_rule()]
#true_rule_f_ls = rule_fs
true_L = len(true_rule_f_ls)
true_p_y_ns_given_theta = hvr.p_y_ns_given_theta(true_rule_f_ls)
true_mu = np.ones(K)*5.0
true_prec = np.eye(K)/1.0
true_lambda_ls = np.ones(true_L) / 1.0
true_delta = np.cumsum(np.arange(1,true_L+1,1))
true_theta = hvr.theta(true_mu, true_prec, np.random.multivariate_normal(true_mu, true_prec, true_L), true_lambda_ls, true_delta)
print 'true delta:', true_delta
print 'true lambdas', true_lambda_ls
print 'true rule_f_ls', true_rule_f_ls
print 'supports', pd.Series(true_p_y_ns_given_theta.get_z_ns_num(x_ns)).value_counts()
# Out:
# true delta: [ 1  3  6 10]
# true lambdas [ 1.  1.  1.  1.]
# true rule_f_ls [bin0_1, bin1_1, bin2_1, default]
# supports 0    2574
# 1    1215
# 3     638
# 2     573
# dtype: int64

# %%
# simulate y_ns
y_ns = true_p_y_ns_given_theta.sample(true_theta, (x_ns,T_ns))

# %%
# define p_theta
v_0 = 66.0001
assert v_0 > K-1
T_0 = 1.0 * np.eye(K) 
c_0 = .0001 
m_0 = np.zeros(K)
alpha_0 = 1.
beta_0 = 1.
r_0 = -1000.
s_0 = 1000.
p_theta = hvr.p_theta(v_0, T_0, c_0, m_0, alpha_0, beta_0, r_0, s_0)

# %%
# define get_posterior_f
recovery_num_iters = 15
recovery_get_posterior_f = hvr.get_posterior_f(recovery_num_iters)

# %%
#for true model, try to recover true theta
true_model = hvr.model(p_theta, true_p_y_ns_given_theta)
v, T, c, m, mu_B_ls, prec_B_ls, alpha_lambda_ls, beta_lambda_ls, mu_delta, prec_delta = recovery_get_posterior_f(true_model, (x_ns, T_ns), y_ns)
print 'v',v
print 'T',T 
print 'c',c
print 'm',m
print 'mu_B_ls', mu_B_ls
print 'prec_B_ls', prec_B_ls
print 'alpha_lambda_ls', alpha_lambda_ls
print 'beta_lambda_ls', beta_lambda_ls
print 'mu_delta', mu_delta
print 'prec_delta',prec_delta
print 'mu_lambda_ls', alpha_lambda_ls / beta_lambda_ls
# Out:
# v 70.0001
# T [[ 0.9305402   0.01180504  0.08144274 -0.03060717]
#  [ 0.01180504  0.95836017 -0.05244916  0.04186341]
#  [ 0.08144274 -0.05244916  0.64547799  0.22040556]
#  [-0.03060717  0.04186341  0.22040556  0.57597806]]
# c 4.0001
# m [ 2.96460495  3.72926249  5.7555861   4.22150463]
# mu_B_ls [[ 3.13007924  3.65170523  5.22703972  4.3343088 ]
#  [ 2.87386118  3.85183523  6.46293995  3.39212671]
#  [ 2.99197193  3.69987917  5.64496805  4.74785725]
#  [ 2.97687061  3.71715944  5.68837907  4.41091417]]
# prec_B_ls [array([[ 2642.66846778,  1303.61083679,  1294.46628025,  1274.60631575],
#        [ 1303.61083679,  1369.86979061,   657.23382545,   660.83159977],
#        [ 1294.46628025,   657.23382545,  1333.94880404,   663.31585186],
#        [ 1274.60631575,   660.83159977,   663.31585186,  1317.06734247]]), array([[  6.51379073e+01,   8.26353794e-01,   5.70099999e+00,
#          -2.14250502e+00],
#        [  8.26353794e-01,   1.28932536e+03,   6.21029024e+02,
#           6.79940775e+02],
#        [  5.70099999e+00,   6.21029024e+02,   6.69883994e+02,
#           3.45382927e+02],
#        [ -2.14250502e+00,   6.79940775e+02,   3.45382927e+02,
#           7.17328854e+02]]), array([[  65.13790726,    0.82635379,    5.70099999,   -2.14250502],
#        [   0.82635379,   67.08530761,   -3.67144648,    2.93044271],
#        [   5.70099999,   -3.67144648,  661.06050691,  319.60500132],
#        [  -2.14250502,    2.93044271,  319.60500132,  344.49511197]]), array([[  65.13790726,    0.82635379,    5.70099999,   -2.14250502],
#        [   0.82635379,   67.08530761,   -3.67144648,    2.93044271],
#        [   5.70099999,   -3.67144648,   45.18352378,   15.42841104],
#        [  -2.14250502,    2.93044271,   15.42841104,  358.16322274]])]
# alpha_lambda_ls [ 1288.    608.5   287.5   320. ]
# beta_lambda_ls [ 1286.1869525    604.89467836   267.48341015   310.08881581]
# mu_delta [ 1.00671582  2.93987207  6.08978053  9.98773776]
# prec_delta [[ 2484.09188771  1185.31289121   601.8567352    311.65292115]
#  [ 1185.31289121  1185.31289121   601.8567352    311.65292115]
#  [  601.8567352    601.8567352    601.8567352    311.65292115]
#  [  311.65292115   311.65292115   311.65292115   311.65292115]]
# mu_lambda_ls [ 1.00140963  1.00596025  1.07483301  1.0319624 ]

# %%
# define list of models to calculate evidence for
candidate_models = [hvr.model. model_from_p_theta_and_rule_fs(p_theta, list(rule_fs)) for rule_fs in hvr.subsequence_iterator(all_rule_fs)]
print len(candidate_models)
# Out:
# 64

# %%
# define function to calculate evidence lower bound
num_iters = 5
get_posterior_f = hvr.get_posterior_f(num_iters)
get_evidence_f = hvr.get_evidence_f(get_posterior_f, hvr.log_evidence_lower_bound)

# %%
# calculate evidence for each model
results = []

@basic.do_cprofile
def run():
    for candidate_model in candidate_models:
        print candidate_model
        results.append([repr(candidate_model),get_evidence_f(candidate_model, (x_ns, T_ns), y_ns)])
run()
print results
# Out:
# [bin0_1, default]
# [bin1_1, default]
# [bin2_1, default]
# [bin3_1, default]
# [bin0_1, bin1_1, default]
# [bin0_1, bin2_1, default]
# [bin0_1, bin3_1, default]
# [bin1_1, bin0_1, default]
# [bin1_1, bin2_1, default]
# [bin1_1, bin3_1, default]
# [bin2_1, bin0_1, default]
# [bin2_1, bin1_1, default]
# [bin2_1, bin3_1, default]
# [bin3_1, bin0_1, default]
# [bin3_1, bin1_1, default]
# [bin3_1, bin2_1, default]
# [bin0_1, bin1_1, bin2_1, default]
# [bin0_1, bin1_1, bin3_1, default]
# [bin0_1, bin2_1, bin1_1, default]
# [bin0_1, bin2_1, bin3_1, default]
# [bin0_1, bin3_1, bin1_1, default]
# [bin0_1, bin3_1, bin2_1, default]
# [bin1_1, bin0_1, bin2_1, default]
# [bin1_1, bin0_1, bin3_1, default]
# [bin1_1, bin2_1, bin0_1, default]
# [bin1_1, bin2_1, bin3_1, default]
# [bin1_1, bin3_1, bin0_1, default]
# [bin1_1, bin3_1, bin2_1, default]
# [bin2_1, bin0_1, bin1_1, default]
# [bin2_1, bin0_1, bin3_1, default]
# [bin2_1, bin1_1, bin0_1, default]
# [bin2_1, bin1_1, bin3_1, default]
# [bin2_1, bin3_1, bin0_1, default]
# [bin2_1, bin3_1, bin1_1, default]
# [bin3_1, bin0_1, bin1_1, default]
# [bin3_1, bin0_1, bin2_1, default]
# [bin3_1, bin1_1, bin0_1, default]
# [bin3_1, bin1_1, bin2_1, default]
# [bin3_1, bin2_1, bin0_1, default]
# [bin3_1, bin2_1, bin1_1, default]
# [bin0_1, bin1_1, bin2_1, bin3_1, default]
# [bin0_1, bin1_1, bin3_1, bin2_1, default]
# [bin0_1, bin2_1, bin1_1, bin3_1, default]
# [bin0_1, bin2_1, bin3_1, bin1_1, default]
# [bin0_1, bin3_1, bin1_1, bin2_1, default]
# [bin0_1, bin3_1, bin2_1, bin1_1, default]
# [bin1_1, bin0_1, bin2_1, bin3_1, default]
# [bin1_1, bin0_1, bin3_1, bin2_1, default]
# [bin1_1, bin2_1, bin0_1, bin3_1, default]
# [bin1_1, bin2_1, bin3_1, bin0_1, default]
# [bin1_1, bin3_1, bin0_1, bin2_1, default]
# [bin1_1, bin3_1, bin2_1, bin0_1, default]
# [bin2_1, bin0_1, bin1_1, bin3_1, default]
# [bin2_1, bin0_1, bin3_1, bin1_1, default]
# [bin2_1, bin1_1, bin0_1, bin3_1, default]
# [bin2_1, bin1_1, bin3_1, bin0_1, default]
# [bin2_1, bin3_1, bin0_1, bin1_1, default]
# [bin2_1, bin3_1, bin1_1, bin0_1, default]
# [bin3_1, bin0_1, bin1_1, bin2_1, default]
# [bin3_1, bin0_1, bin2_1, bin1_1, default]
# [bin3_1, bin1_1, bin0_1, bin2_1, default]
# [bin3_1, bin1_1, bin2_1, bin0_1, default]
# [bin3_1, bin2_1, bin0_1, bin1_1, default]
# [bin3_1, bin2_1, bin1_1, bin0_1, default]
#          1690073 function calls (1686745 primitive calls) in 56.955 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002   56.955   56.955 <ipython-input-18-a48f01906ab0>:4(run)
#      1088    0.005    0.000    0.263    0.000 __init__.py:140(_)
#      1088    0.000    0.000    0.000    0.000 __init__.py:179(_)
#       252    0.001    0.000    0.007    0.000 __init__.py:193(dumps)
# 2176/1088    0.010    0.000    0.288    0.000 __init__.py:278(__getattribute__)
#      1088    0.005    0.000    0.277    0.000 __init__.py:289(__getitem__)
#      1088    0.011    0.000   52.328    0.048 __init__.py:309(__call__)
#      5440    0.050    0.000    0.129    0.000 __init__.py:84(sexpvector_to_ro)
#      2176    0.035    0.000    0.058    0.000 _abcoll.py:526(update)
#      9888    0.012    0.000    0.149    0.000 _methods.py:23(_sum)
#       128    0.000    0.000    0.001    0.000 _methods.py:31(_any)
#      6528    0.006    0.000    0.006    0.000 _weakrefset.py:68(__contains__)
#      2176    0.007    0.000    0.011    0.000 abc.py:128(__instancecheck__)
#      2176    0.004    0.000    0.007    0.000 abc.py:148(__subclasscheck__)
#        63    0.000    0.000    0.001    0.000 attrsettr.py:35(__getattr__)
#      1088    0.011    0.000    0.053    0.000 collections.py:38(__init__)
#      3264    0.005    0.000    0.005    0.000 collections.py:54(__setitem__)
#      2524    0.015    0.000    0.031    0.000 copy.py:145(deepcopy)
#      2524    0.009    0.000    0.010    0.000 copy.py:267(_keep_alive)
#       252    0.000    0.000    0.000    0.000 encoder.py:101(__init__)
#       252    0.001    0.000    0.006    0.000 encoder.py:186(encode)
#       252    0.002    0.000    0.005    0.000 encoder.py:212(iterencode)
#      1638    0.001    0.000    0.003    0.000 encoder.py:33(encode_basestring)
#        63    0.000    0.000    0.000    0.000 encoder.py:37(replace)
#      9888    0.022    0.000    0.178    0.000 fromnumeric.py:1621(sum)
#       128    0.000    0.000    0.002    0.000 fromnumeric.py:1762(any)
#      1088   51.878    0.048   51.946    0.048 functions.py:101(__call__)
#      1088    0.003    0.000    0.036    0.000 functions.py:110(formals)
#      1088    0.025    0.000    0.258    0.000 functions.py:134(__init__)
#      4352    0.002    0.000    0.002    0.000 functions.py:166(<genexpr>)
#      1088    0.005    0.000   51.952    0.048 functions.py:171(__call__)
#      1088    0.012    0.000    0.012    0.000 functions.py:25(_formals_fixed)
#      1088    0.018    0.000    0.018    0.000 functions.py:83(__init__)
#        64    0.092    0.001    6.766    0.106 hier_treatment_variational_regr.py:180(log_evidence_lower_bound)
#        64    0.003    0.000    0.006    0.000 hier_treatment_variational_regr.py:29(init_variational_params)
#       392    0.001    0.000    0.001    0.000 hier_treatment_variational_regr.py:334(__repr__)
#   1085192    1.091    0.000    1.091    0.000 hier_treatment_variational_regr.py:337(__call__)
#       128    0.000    0.000    0.000    0.000 hier_treatment_variational_regr.py:351(__repr__)
#     95288    0.011    0.000    0.011    0.000 hier_treatment_variational_regr.py:354(__call__)
#       128    1.083    0.008    2.191    0.017 hier_treatment_variational_regr.py:378(get_z_ns_num)
#       128    0.020    0.000    2.213    0.017 hier_treatment_variational_regr.py:388(get_z_ns)
#       128    0.000    0.000    0.002    0.000 hier_treatment_variational_regr.py:400(__repr__)
#        64    0.002    0.000   48.961    0.765 hier_treatment_variational_regr.py:419(__call__)
#        64    0.002    0.000   56.922    0.889 hier_treatment_variational_regr.py:431(__call__)
#        64    0.710    0.011   47.933    0.749 hier_treatment_variational_regr.py:53(infer_variational_params)
#       584    0.000    0.000    0.000    0.000 hier_variational_regr.py:13(debug_print)
#       256    0.001    0.000    0.003    0.000 hier_variational_regr.py:289(k_ls_f)
#       128    0.001    0.000    0.008    0.000 hier_variational_regr.py:293(k_ls_k_ls_T_f)
#      1688    0.006    0.000    0.006    0.000 hier_variational_regr.py:298(E_prec_f)
#      1624    0.006    0.000    0.010    0.000 hier_variational_regr.py:303(E_prec_mu_f)
#       320    0.005    0.000    0.014    0.000 hier_variational_regr.py:310(E_log_det_prec_f)
#       128    0.001    0.000    0.003    0.000 hier_variational_regr.py:317(E_trace_prec_mu_mu_T_f)
#        64    0.001    0.000    0.011    0.000 hier_variational_regr.py:324(H_mu_prec_f)
#      1820    0.003    0.000    0.025    0.000 hier_variational_regr.py:342(E_B_l_f)
#       704    0.002    0.000    0.011    0.000 hier_variational_regr.py:346(E_B_ls_f)
#      3380    0.017    0.000    0.164    0.000 hier_variational_regr.py:350(E_B_l_B_l_T_f)
#       324    0.002    0.000    0.008    0.000 hier_variational_regr.py:357(H_B_l_f)
#      3120    0.002    0.000    0.002    0.000 hier_variational_regr.py:364(E_lambda_l_f)
#       704    0.002    0.000    0.002    0.000 hier_variational_regr.py:368(E_lambda_ls_f)
#       260    0.002    0.000    0.002    0.000 hier_variational_regr.py:372(E_log_lambda_l_f)
#        64    0.000    0.000    0.000    0.000 hier_variational_regr.py:380(E_log_lambda_ls_f)
#       260    0.002    0.000    0.002    0.000 hier_variational_regr.py:384(H_lambda_l_f)
#       128    0.002    0.000    0.012    0.000 hier_variational_regr.py:388(wishart_log_Z_f)
#      1088    0.069    0.000   52.594    0.048 hier_variational_regr.py:401(horse)
#       704    0.002    0.000   34.332    0.049 hier_variational_regr.py:431(mean)
#       384    0.004    0.000   18.278    0.048 hier_variational_regr.py:439(E_xx_T)
#       704    0.002    0.000   34.334    0.049 hier_variational_regr.py:448(E_delta_f)
#       384    0.001    0.000   18.279    0.048 hier_variational_regr.py:456(E_delta_delta_T_f)
#        63    0.000    0.000    0.000    0.000 hmac.py:116(hexdigest)
#        63    0.000    0.000    0.000    0.000 hmac.py:27(__init__)
#       252    0.000    0.000    0.001    0.000 hmac.py:80(update)
#        63    0.000    0.000    0.001    0.000 hmac.py:85(copy)
#        63    0.000    0.000    0.000    0.000 hmac.py:97(_current)
#       191    0.000    0.000    0.000    0.000 iostream.py:102(_check_mp_mode)
#        63    0.000    0.000    0.002    0.000 iostream.py:123(_flush_from_subprocesses)
#        63    0.001    0.000    0.027    0.000 iostream.py:151(flush)
#       128    0.001    0.000    0.029    0.000 iostream.py:207(write)
#        63    0.000    0.000    0.000    0.000 iostream.py:238(_flush_buffer)
#        63    0.000    0.000    0.000    0.000 iostream.py:247(_new_buffer)
#       254    0.000    0.000    0.000    0.000 iostream.py:93(_is_master_process)
#        63    0.000    0.000    0.000    0.000 iostream.py:96(_is_master_thread)
#       252    0.001    0.000    0.008    0.000 jsonapi.py:31(dumps)
#        63    0.000    0.000    0.000    0.000 jsonutil.py:102(date_default)
#      6792    0.009    0.000    0.009    0.000 linalg.py:101(get_linalg_error_extobj)
#      6792    0.009    0.000    0.022    0.000 linalg.py:106(_makearray)
#     15128    0.006    0.000    0.009    0.000 linalg.py:111(isComplexType)
#      7564    0.005    0.000    0.006    0.000 linalg.py:124(_realType)
#      7564    0.021    0.000    0.035    0.000 linalg.py:139(_commonType)
#       772    0.007    0.000    0.015    0.000 linalg.py:1679(det)
#      7564    0.010    0.000    0.011    0.000 linalg.py:198(_assertRankAtLeast2)
#      7564    0.010    0.000    0.016    0.000 linalg.py:209(_assertNdSquareness)
#       772    0.001    0.000    0.001    0.000 linalg.py:219(_assertNoEmpty2d)
#      6792    0.127    0.000    0.232    0.000 linalg.py:455(inv)
#       320    0.000    0.000    0.001    0.000 numeric.py:136(ones)
#       128    0.000    0.000    0.000    0.000 numeric.py:1810(isscalar)
#     21108    0.013    0.000    0.027    0.000 numeric.py:392(asarray)
#       128    0.000    0.000    0.000    0.000 numeric.py:462(asanyarray)
#      6676    0.064    0.000    0.087    0.000 numeric.py:966(outer)
#      3264    0.002    0.000    0.004    0.000 packages_utils.py:23(default_symbol_r2python)
#      1088    0.004    0.000    0.004    0.000 packages_utils.py:26(default_symbol_check_after)
#      1088    0.012    0.000    0.028    0.000 packages_utils.py:57(_map_symbols)
#      1088    0.001    0.000    0.001    0.000 packages_utils.py:81(_fix_map_symbols)
#        63    0.000    0.000    0.001    0.000 poll.py:77(poll)
#        63    0.000    0.000    0.000    0.000 py3compat.py:11(no_code)
#        63    0.000    0.000    0.001    0.000 session.py:195(msg_header)
#        63    0.000    0.000    0.000    0.000 session.py:200(extract_header)
#        63    0.000    0.000    0.005    0.000 session.py:441(msg_id)
#        63    0.000    0.000    0.006    0.000 session.py:493(msg_header)
#        63    0.000    0.000    0.007    0.000 session.py:496(msg)
#        63    0.000    0.000    0.002    0.000 session.py:515(sign)
#        63    0.001    0.000    0.012    0.000 session.py:530(serialize)
#        63    0.001    0.000    0.022    0.000 session.py:589(send)
#       252    0.000    0.000    0.009    0.000 session.py:84(<lambda>)
#      7616    0.015    0.000    0.023    0.000 singledispatch.py:173(dispatch)
# 7616/5440    0.024    0.000    0.394    0.000 singledispatch.py:209(wrapper)
#        63    0.000    0.000    0.002    0.000 socket.py:250(send_multipart)
#       128    0.005    0.000    0.008    0.000 spfun_stats.py:45(multigammaln)
#      3264    0.002    0.000    0.003    0.000 string.py:308(join)
#        63    0.000    0.000    0.000    0.000 threading.py:1152(currentThread)
#        63    0.000    0.000    0.000    0.000 threading.py:983(ident)
#       819    0.001    0.000    0.001    0.000 traitlets.py:395(__get__)
#       324    0.001    0.000    0.002    0.000 twodim_base.py:170(eye)
#        64    0.000    0.000    0.001    0.000 twodim_base.py:221(diag)
#       128    0.000    0.000    0.000    0.000 utf_8.py:15(decode)
#        63    0.001    0.000    0.002    0.000 uuid.py:101(__init__)
#        63    0.000    0.000    0.000    0.000 uuid.py:197(__str__)
#        63    0.001    0.000    0.004    0.000 uuid.py:533(uuid4)
#      5440    0.003    0.000    0.003    0.000 vectors.py:141(__init__)
#      5440    0.038    0.000    0.051    0.000 vectors.py:231(__init__)
#      7616    0.016    0.000    0.074    0.000 vectors.py:244(__getitem__)
#      1088    0.006    0.000    0.032    0.000 vectors.py:261(_names_get)
#      1088    0.003    0.000    0.014    0.000 vectors.py:353(__init__)
#     10880    0.009    0.000    0.009    0.000 vectors.py:42(__init__)
#      1088    0.003    0.000    0.014    0.000 vectors.py:445(__init__)
#      1088    0.007    0.000    0.023    0.000 vectors.py:535(__init__)
#      1088    0.008    0.000    0.014    0.000 vectors.py:748(__init__)
#      7616    0.009    0.000    0.009    0.000 weakref.py:255(__getitem__)
#       128    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#        64    0.000    0.000    0.000    0.000 {abs}
#        63    0.000    0.000    0.000    0.000 {built-in method now}
#      1088    0.039    0.000    0.039    0.000 {dir}
#     11555    0.004    0.000    0.004    0.000 {getattr}
#      4415    0.004    0.000    0.005    0.000 {hasattr}
#      7572    0.001    0.000    0.001    0.000 {id}
#     25485    0.013    0.000    0.023    0.000 {isinstance}
#     25216    0.007    0.000    0.007    0.000 {issubclass}
#     23100    0.004    0.000    0.004    0.000 {len}
#        63    0.000    0.000    0.000    0.000 {locals}
#      3327    0.030    0.000    0.030    0.000 {map}
#      7627    0.004    0.000    0.004    0.000 {max}
#      6792    0.001    0.000    0.001    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#      2524    0.003    0.000    0.003    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#       128    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#      3517    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       772    0.002    0.000    0.002    0.000 {method 'astype' of 'numpy.generic' objects}
#     12772    0.062    0.000    0.062    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        63    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#       189    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#        63    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        63    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#       128    0.000    0.000    0.001    0.000 {method 'decode' of 'str' objects}
#        63    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     10880    0.007    0.000    0.007    0.000 {method 'do_slot' of 'rpy2.rinterface.Sexp' objects}
#     12576    0.219    0.000    0.219    0.000 {method 'dot' of 'numpy.ndarray' objects}
#       189    0.000    0.000    0.000    0.000 {method 'encode' of 'unicode' objects}
#       126    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#     12675    0.003    0.000    0.003    0.000 {method 'get' of 'dict' objects}
#      2176    0.005    0.000    0.005    0.000 {method 'get' of 'rpy2.rinterface.SexpEnvironment' objects}
#        63    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        63    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#        63    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        63    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#      5440    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      3516    0.002    0.000    0.002    0.000 {method 'join' of 'str' objects}
#      1088    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     13352    0.007    0.000    0.007    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     10016    0.138    0.000    0.138    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      3264    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#      1088    0.003    0.000    0.003    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       441    0.002    0.000    0.002    0.000 {method 'send' of 'zmq.backend.cython.socket.Socket' objects}
#      1638    0.002    0.000    0.002    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#       315    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#      1088    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#        63    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       128    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#      7564    0.002    0.000    0.002    0.000 {min}
#       448    0.002    0.000    0.002    0.000 {numpy.core.multiarray.arange}
#     23668    0.032    0.000    0.032    0.000 {numpy.core.multiarray.array}
#       320    0.001    0.000    0.001    0.000 {numpy.core.multiarray.copyto}
#       320    0.000    0.000    0.000    0.000 {numpy.core.multiarray.empty}
#      2116    0.005    0.000    0.005    0.000 {numpy.core.multiarray.zeros}
#       317    0.000    0.000    0.000    0.000 {posix.getpid}
#        63    0.002    0.000    0.002    0.000 {posix.urandom}
#       191    0.000    0.000    0.000    0.000 {range}
#   192/128    0.001    0.000    0.002    0.000 {repr}
#      1088    0.077    0.000    0.077    0.000 {rpy2.rinterface._rinterface.parse}
#       260    0.500    0.002    0.500    0.002 {sum}
#        63    0.000    0.000    0.000    0.000 {thread.get_ident}
#       128    0.000    0.000    0.000    0.000 {time.time}
#        63    0.001    0.000    0.001    0.000 {zmq.backend.cython._poll.zmq_poll}
#
#
# [['[bin0_1, default]', -24770.168576132495], ['[bin1_1, default]', -25792.019508356469], ['[bin2_1, default]', -27138.438856333669], ['[bin3_1, default]', -27967.736811530231], ['[bin0_1, bin1_1, default]', -22626.957659570056], ['[bin0_1, bin2_1, default]', -24101.424555969195], ['[bin0_1, bin3_1, default]', -24699.210445648692], ['[bin1_1, bin0_1, default]', -23724.897069868824], ['[bin1_1, bin2_1, default]', -25380.46946792983], ['[bin1_1, bin3_1, default]', -25809.758816829581], ['[bin2_1, bin0_1, default]', -26201.055804873202], ['[bin2_1, bin1_1, default]', -26059.203883191316], ['[bin2_1, bin3_1, default]', -27146.692182950737], ['[bin3_1, bin0_1, default]', -27630.297342335096], ['[bin3_1, bin1_1, default]', -27610.046462567243], ['[bin3_1, bin2_1, default]', -27635.170397127462], ['[bin0_1, bin1_1, bin2_1, default]', -21332.040374044154], ['[bin0_1, bin1_1, bin3_1, default]', -22640.220592793838], ['[bin0_1, bin2_1, bin1_1, default]', -22976.083377067567], ['[bin0_1, bin2_1, bin3_1, default]', -24112.229182495026], ['[bin0_1, bin3_1, bin1_1, default]', -24676.184177310526], ['[bin0_1, bin3_1, bin2_1, default]', -24582.034454323915], ['[bin1_1, bin0_1, bin2_1, default]', -22687.182803343578], ['[bin1_1, bin0_1, bin3_1, default]', -23835.18175655256], ['[bin1_1, bin2_1, bin0_1, default]', -24277.148280924092], ['[bin1_1, bin2_1, bin3_1, default]', -25401.181354738837], ['[bin1_1, bin3_1, bin0_1, default]', -25809.867005019285], ['[bin1_1, bin3_1, bin2_1, default]', -25775.697868204312], ['[bin2_1, bin0_1, bin1_1, default]', -24802.035639468075], ['[bin2_1, bin0_1, bin3_1, default]', -26255.715200715891], ['[bin2_1, bin1_1, bin0_1, default]', -24644.489390112365], ['[bin2_1, bin1_1, bin3_1, default]', -26145.759973810305], ['[bin2_1, bin3_1, bin0_1, default]', -27112.417095960667], ['[bin2_1, bin3_1, bin1_1, default]', -27088.905514403181], ['[bin3_1, bin0_1, bin1_1, default]', -27204.445115912586], ['[bin3_1, bin0_1, bin2_1, default]', -27520.648180535867], ['[bin3_1, bin1_1, bin0_1, default]', -27090.027412636995], ['[bin3_1, bin1_1, bin2_1, default]', -27483.550295654288], ['[bin3_1, bin2_1, bin0_1, default]', -27338.726184861], ['[bin3_1, bin2_1, bin1_1, default]', -27364.634731821647], ['[bin0_1, bin1_1, bin2_1, bin3_1, default]', -21338.999244561517], ['[bin0_1, bin1_1, bin3_1, bin2_1, default]', -22716.454743232462], ['[bin0_1, bin2_1, bin1_1, bin3_1, default]', -23195.973312193812], ['[bin0_1, bin2_1, bin3_1, bin1_1, default]', -24163.246150333798], ['[bin0_1, bin3_1, bin1_1, bin2_1, default]', -24484.182670598468], ['[bin0_1, bin3_1, bin2_1, bin1_1, default]', -24355.738139217101], ['[bin1_1, bin0_1, bin2_1, bin3_1, default]', -22902.768231520895], ['[bin1_1, bin0_1, bin3_1, bin2_1, default]', -23986.721425142649], ['[bin1_1, bin2_1, bin0_1, bin3_1, default]', -24496.549710380888], ['[bin1_1, bin2_1, bin3_1, bin0_1, default]', -25437.098804841164], ['[bin1_1, bin3_1, bin0_1, bin2_1, default]', -25661.343282592763], ['[bin1_1, bin3_1, bin2_1, bin0_1, default]', -25571.500807072607], ['[bin2_1, bin0_1, bin1_1, bin3_1, default]', -25076.506330249649], ['[bin2_1, bin0_1, bin3_1, bin1_1, default]', -26433.484641448813], ['[bin2_1, bin1_1, bin0_1, bin3_1, default]', -24919.801967502903], ['[bin2_1, bin1_1, bin3_1, bin0_1, default]', -26264.505200601507], ['[bin2_1, bin3_1, bin0_1, bin1_1, default]', -26717.01902841319], ['[bin2_1, bin3_1, bin1_1, bin0_1, default]', -26724.505994623742], ['[bin3_1, bin0_1, bin1_1, bin2_1, default]', -26870.313056735977], ['[bin3_1, bin0_1, bin2_1, bin1_1, default]', -27408.972169371478], ['[bin3_1, bin1_1, bin0_1, bin2_1, default]', -26797.895524238163], ['[bin3_1, bin1_1, bin2_1, bin0_1, default]', -27249.876723894122], ['[bin3_1, bin2_1, bin0_1, bin1_1, default]', -26800.501463710341], ['[bin3_1, bin2_1, bin1_1, bin0_1, default]', -26803.345727699641]]

# %%
# print evidence for each model
print len(results)
display_html(pd.DataFrame.from_records(results, columns=['rules','log evidence']).sort(columns=['log evidence']).to_html(), raw=True)
# Out:
# 64
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rules</th>
#       <th>log evidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3 </th>
#       <td>                         [bin3_1, default]</td>
#       <td>-27967.736812</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>                 [bin3_1, bin2_1, default]</td>
#       <td>-27635.170397</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>                 [bin3_1, bin0_1, default]</td>
#       <td>-27630.297342</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>                 [bin3_1, bin1_1, default]</td>
#       <td>-27610.046463</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>         [bin3_1, bin0_1, bin2_1, default]</td>
#       <td>-27520.648181</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>         [bin3_1, bin1_1, bin2_1, default]</td>
#       <td>-27483.550296</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td> [bin3_1, bin0_1, bin2_1, bin1_1, default]</td>
#       <td>-27408.972169</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>         [bin3_1, bin2_1, bin1_1, default]</td>
#       <td>-27364.634732</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>         [bin3_1, bin2_1, bin0_1, default]</td>
#       <td>-27338.726185</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td> [bin3_1, bin1_1, bin2_1, bin0_1, default]</td>
#       <td>-27249.876724</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>         [bin3_1, bin0_1, bin1_1, default]</td>
#       <td>-27204.445116</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>                 [bin2_1, bin3_1, default]</td>
#       <td>-27146.692183</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>                         [bin2_1, default]</td>
#       <td>-27138.438856</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>         [bin2_1, bin3_1, bin0_1, default]</td>
#       <td>-27112.417096</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>         [bin3_1, bin1_1, bin0_1, default]</td>
#       <td>-27090.027413</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>         [bin2_1, bin3_1, bin1_1, default]</td>
#       <td>-27088.905514</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td> [bin3_1, bin0_1, bin1_1, bin2_1, default]</td>
#       <td>-26870.313057</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td> [bin3_1, bin2_1, bin1_1, bin0_1, default]</td>
#       <td>-26803.345728</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td> [bin3_1, bin2_1, bin0_1, bin1_1, default]</td>
#       <td>-26800.501464</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td> [bin3_1, bin1_1, bin0_1, bin2_1, default]</td>
#       <td>-26797.895524</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td> [bin2_1, bin3_1, bin1_1, bin0_1, default]</td>
#       <td>-26724.505995</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td> [bin2_1, bin3_1, bin0_1, bin1_1, default]</td>
#       <td>-26717.019028</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td> [bin2_1, bin0_1, bin3_1, bin1_1, default]</td>
#       <td>-26433.484641</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td> [bin2_1, bin1_1, bin3_1, bin0_1, default]</td>
#       <td>-26264.505201</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>         [bin2_1, bin0_1, bin3_1, default]</td>
#       <td>-26255.715201</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>                 [bin2_1, bin0_1, default]</td>
#       <td>-26201.055805</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>         [bin2_1, bin1_1, bin3_1, default]</td>
#       <td>-26145.759974</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>                 [bin2_1, bin1_1, default]</td>
#       <td>-26059.203883</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>         [bin1_1, bin3_1, bin0_1, default]</td>
#       <td>-25809.867005</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td>                 [bin1_1, bin3_1, default]</td>
#       <td>-25809.758817</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>                         [bin1_1, default]</td>
#       <td>-25792.019508</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>         [bin1_1, bin3_1, bin2_1, default]</td>
#       <td>-25775.697868</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td> [bin1_1, bin3_1, bin0_1, bin2_1, default]</td>
#       <td>-25661.343283</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td> [bin1_1, bin3_1, bin2_1, bin0_1, default]</td>
#       <td>-25571.500807</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td> [bin1_1, bin2_1, bin3_1, bin0_1, default]</td>
#       <td>-25437.098805</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>         [bin1_1, bin2_1, bin3_1, default]</td>
#       <td>-25401.181355</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td>                 [bin1_1, bin2_1, default]</td>
#       <td>-25380.469468</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td> [bin2_1, bin0_1, bin1_1, bin3_1, default]</td>
#       <td>-25076.506330</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td> [bin2_1, bin1_1, bin0_1, bin3_1, default]</td>
#       <td>-24919.801968</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>         [bin2_1, bin0_1, bin1_1, default]</td>
#       <td>-24802.035639</td>
#     </tr>
#     <tr>
#       <th>0 </th>
#       <td>                         [bin0_1, default]</td>
#       <td>-24770.168576</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td>                 [bin0_1, bin3_1, default]</td>
#       <td>-24699.210446</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>         [bin0_1, bin3_1, bin1_1, default]</td>
#       <td>-24676.184177</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>         [bin2_1, bin1_1, bin0_1, default]</td>
#       <td>-24644.489390</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>         [bin0_1, bin3_1, bin2_1, default]</td>
#       <td>-24582.034454</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td> [bin1_1, bin2_1, bin0_1, bin3_1, default]</td>
#       <td>-24496.549710</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td> [bin0_1, bin3_1, bin1_1, bin2_1, default]</td>
#       <td>-24484.182671</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td> [bin0_1, bin3_1, bin2_1, bin1_1, default]</td>
#       <td>-24355.738139</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>         [bin1_1, bin2_1, bin0_1, default]</td>
#       <td>-24277.148281</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td> [bin0_1, bin2_1, bin3_1, bin1_1, default]</td>
#       <td>-24163.246150</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>         [bin0_1, bin2_1, bin3_1, default]</td>
#       <td>-24112.229182</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td>                 [bin0_1, bin2_1, default]</td>
#       <td>-24101.424556</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td> [bin1_1, bin0_1, bin3_1, bin2_1, default]</td>
#       <td>-23986.721425</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>         [bin1_1, bin0_1, bin3_1, default]</td>
#       <td>-23835.181757</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td>                 [bin1_1, bin0_1, default]</td>
#       <td>-23724.897070</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td> [bin0_1, bin2_1, bin1_1, bin3_1, default]</td>
#       <td>-23195.973312</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>         [bin0_1, bin2_1, bin1_1, default]</td>
#       <td>-22976.083377</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td> [bin1_1, bin0_1, bin2_1, bin3_1, default]</td>
#       <td>-22902.768232</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td> [bin0_1, bin1_1, bin3_1, bin2_1, default]</td>
#       <td>-22716.454743</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>         [bin1_1, bin0_1, bin2_1, default]</td>
#       <td>-22687.182803</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>         [bin0_1, bin1_1, bin3_1, default]</td>
#       <td>-22640.220593</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td>                 [bin0_1, bin1_1, default]</td>
#       <td>-22626.957660</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td> [bin0_1, bin1_1, bin2_1, bin3_1, default]</td>
#       <td>-21338.999245</td>
#     </tr>
#     <tr>

# %%
# define simulated annealing model fitter
SA_num_iters = 1500
temperature = 1.
def reject_f(model,(x_ns,T_ns), y_ns): 
    return np.sum(model.p_y_ns_given_theta.get_z_ns(x_ns), axis=0).min() < 10
model_fitter = hvr.simulated_annealing_model_fitter(all_rule_fs, p_theta, SA_num_iters, temperature, get_evidence_f, reject_f)

# %%
# run simulated annealing
#best_model, best_evidence = model_fitter((x_ns, T_ns), y_ns)
#print best_model, best_evidence
