# %%
import domain_adapt_run.domain_adapt_run.constants as constants
cache_folder_name = 'supervised_weighted_least_squares'
seed = 44

# %%
import autograd.numpy as np
np.random.seed(seed)
import python_utils.python_utils.basic as basic
import python_utils.python_utils.caching as caching
log_folder = '%s/%s' % (constants.cache_folder, cache_folder_name)
caching.init(constants.cache_folder, constants.which_hash, basic.archiver(log_folder))
# %load_ext autoreload
# %autoreload 2
# Out:
# [Errno 17] File exists: '/Users/fultonw/Documents/projects/runs/domain_adapt_run/cache/supervised_weighted_least_squares'

# %%
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display_pretty, display_html
import python_utils.python_utils.basic as basic
import pandas as pd
import pdb
import itertools
import functools
import scipy.stats, scipy
import cvxopt
import domain_adapt.domain_adapt.kernels as kernels
import pymanopt
import pprint, autograd
import scipy.optimize
import domain_adapt.domain_adapt.SDR_data as SDR_data
import domain_adapt.domain_adapt.SDR_constructor as SDR_constructor
import sklearn
from sklearn import grid_search, linear_model, pipeline
from sklearn.metrics import roc_curve, auc
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
# get data
import data.readmissions.readmissions.fxns as readmissions_data
num_source = 500
num_target = 500
source_data = readmissions_data.bwh_orig_data()
source_data = source_data.reindex(np.random.permutation(source_data.index))
target_data = readmissions_data.mgh_data()
target_data = target_data.reindex(np.random.permutation(target_data.index))
source_X_df = pd.concat((source_data.iloc[0:num_source,0:-1], pd.DataFrame({'bias':np.ones(num_source)},index=source_data.index[0:num_source])),axis=1, join='inner')
target_X_df = pd.concat((target_data.iloc[0:num_target,0:-1], pd.DataFrame({'bias':np.ones(num_target)},index=target_data.index[0:num_target])),axis=1, join='inner')
feature_names = source_X_df.columns
source_X = source_X_df.values
target_X = target_X_df.values
source_y = source_data.iloc[0:num_source,-1].values
target_y = target_data.iloc[0:num_target,-1].values
print source_X.shape, source_y.shape
feature_names = source_X_df.columns
shift_X, shift_y = kernels.matrices_to_shift_Xy(source_X, target_X, source_y, target_y)
# Out:
# (500, 38) (500,)

# %%
print source_X_df.shape, source_X_df.columns.shape
feature_names.shape
# Out:
# (500, 38) (38,)
# (38,)

# %%
# constants not cross validated
num_trials = 1
num_anneals = 1
B_max = 10
KMM_eps = 0.001
desired_dim = 5
lin_solver = lambda A,b: scipy.sparse.linalg.lsmr(A,b)[0]
cvxopt_solver = kernels.cvxopt_solver
get_KMM_get_K = lambda P,step, xs_train, xs_test: functools.partial(kernels.get_gaussian_K, 1.*kernels.median_distance(np.dot(np.vstack((xs_train,xs_test)),P),np.dot(np.vstack((xs_train,xs_test)),P)))
get_SDR_get_K = lambda P,step, xs1, xs2: lambda xs1, xs2: xs1
get_SDR_get_Ky = lambda P,step, ys1, ys2: lambda ys1, ys2: ys1
get_weight_estimator_get_K = lambda us_train, us_test: functools.partial(kernels.get_gaussian_K, kernels.median_distance(us_train, us_test))
weight_estimator = lambda us_train, us_test: kernels.get_KMM_ws(B_max, KMM_eps, get_weight_estimator_get_K(us_train,us_test), us_train, us_test)
def downstream_estimator_scorer(estimator, shift_X, shift_y, fit_params):
    source_X, target_X, source_y, target_y, source_ws = kernels.shift_Xy_to_matrices(shift_X, shift_y, weights=True)
    return kernels.logloss(source_y, estimator.source_predict(shift_X), source_ws)
downstream_estimator_params = {'C':np.exp2([-2,0,2,4,6])}
downstream_estimator = grid_search.GridSearchCV(kernels.shiftLogisticRegression(fit_intercept=False), param_grid=downstream_estimator_params, cv=2, scoring=downstream_estimator_scorer)

# %%
#
#regs = [0.1,1.,5.,10.,25.]
regs = [1.]
#tradeoffs = [0.1,1.,10]
#tradeoffs = [0.0001]
tradeoffs = [.01]

# %%
#
def get_pipeline_param(reg, tradeoff):
    obj_from_wsopt_and_Ks, dobj_dwsopt, get_dobj_dP_thru_Ku = SDR_constructor.get_logreg_obj_and_gradients(lin_solver, cvxopt_solver, tradeoff, reg)
    horse = functools.partial(SDR_constructor.get_noplot_SDR_horse, desired_dim, num_trials, num_anneals, lin_solver, cvxopt_solver, B_max, KMM_eps, get_KMM_get_K, get_SDR_get_K, get_SDR_get_Ky, obj_from_wsopt_and_Ks, dobj_dwsopt, get_dobj_dP_thru_Ku)
    return {'projection_estimator__horse':[horse],'weighted_estimator__downstream_estimator':[downstream_estimator],'weighted_estimator__weight_estimator':[weight_estimator]}

# %%
# 
cv_base_estimator = pipeline.Pipeline([('projection_estimator',kernels.projection_estimator(feature_names=feature_names)),('weighted_estimator',kernels.weighted_estimator())])
cv_estimator_params = [get_pipeline_param(reg, tradeoff) for tradeoff in tradeoffs for reg in regs]
use_frac = 0.05
def shift_scorer(loss, estimator, shift_X, shift_y):
    use_shift_X = shift_X[0:int(use_frac*len(shift_X))]
    use_shift_y = shift_y[0:int(use_frac*len(shift_y))]
    ys_hat = estimator.predict(use_shift_X) # assumes estimator predicts target, not source
    source_X, target_X, source_y, target_y = kernels.shift_Xy_to_matrices(use_shift_X, use_shift_y)
    return loss(target_y, ys_hat) 
estimator_scorer = functools.partial(shift_scorer, kernels.logloss)
cv_estimator = grid_search.GridSearchCV(cv_base_estimator, param_grid=cv_estimator_params, cv=2, scoring=estimator_scorer)

# %%
from scipy import interp
import matplotlib
matplotlib.rcParams.update({'font.size': 16})
fig, ax = plt.subplots()
fpr_points = np.linspace(0.,1.,101)
roc_curves = []
auc_vals = []
color = 'r'
label = 'asdf'
from sklearn.cross_validation import KFold
outer_cv = sklearn.cross_validation.KFold(num_source, 5)
for (i,(train, test)) in enumerate(reversed(list(outer_cv))):
    print 'cv', i
    shift_X_train, shift_y_train = [shift_X[idx] for idx in train], [shift_y[idx] for idx in train]
    shift_X_test, shift_y_test = [shift_X[idx] for idx in test], [shift_y[idx] for idx in test]
    cv_estimator.fit(shift_X_train, shift_y_train)
    target_y_test_hat = cv_estimator.predict(shift_X_test)
    source_X_test, target_X_test, source_y_test, target_y_test = kernels.shift_Xy_to_matrices(shift_X_test, shift_y_test)
    fpr, tpr, thresholds = roc_curve(target_y_test, target_y_test_hat)
    auc_vals.append(auc(fpr,tpr))
    roc_curves.append(interp(fpr_points, fpr, tpr))
    ax.plot(fpr, tpr, color = color, alpha=0.75, zorder=np.random.random())
    basic.display_fig_inline(fig)
roc_curves_df = pd.DataFrame(roc_curves, columns=fpr_points)
ax.plot(fpr_points, roc_curves_df.mean(), linewidth=5, color=color, label=label)
ax.set_xlabel('fpr',fontsize=22)
ax.set_ylabel('tpr',fontsize=22)
print pd.Series(auc_vals), 'mean:', np.mean(auc_vals), 'std:', np.std(auc_vals)
basic.display_fig_inline(fig)
# Out:
# cv 0
# v_0
# bias                       0.413744
# Jail                       0.297634
# FallRisk                   0.273592
# NegativeIdeation           0.255083
# PositiveSocialSituation   -0.252569
# PoorHousing               -0.228649
# PoorSocialSupport          0.226821
# CMP                        0.209998
# PoorMentalStatus          -0.201912
# PoorPhysical              -0.163644
# dtype: float64
# v_1
# PoorHealthLiteracy        0.439838
# ClinicalTroubles         -0.318391
# NegativeIdeation         -0.293107
# Pain                     -0.275855
# SchedulingDifficulties    0.258579
# PoorMentalStatus          0.249674
# MoodProblems              0.245095
# bias                      0.202135
# AtRisk                   -0.190671
# FinancialProblems         0.181450
# dtype: float64
# v_2
# Jail                          0.361797
# AtRisk                        0.339311
# TransportationDifficulties    0.319308
# CMP                          -0.295571
# ClinicalTroubles             -0.277976
# PoorPhysical                 -0.268822
# PositiveCognitiveIssues      -0.219870
# Noshow                        0.216280
# PoorHousing                  -0.214839
# PositivePhysical             -0.181844
# dtype: float64
# v_3
# Noshow                     0.437864
# DifficultBehavior          0.420523
# PoorPrognosis              0.365480
# PoorMentalStatus          -0.271105
# PoorCompetency            -0.228234
# NeedsMovementAssist        0.224497
# PositiveSocialSituation    0.211602
# NonCompliance             -0.204065
# SubstanceAbuse             0.175366
# FallRisk                  -0.164594
# dtype: float64
# v_4
# FinancialProblems              0.433110
# ProblemsFollowingMeds         -0.300305
# MaxCare                       -0.287472
# NonCompliance                  0.285027
# HistoryofMultipleAdmissions    0.281522
# PositivePhysical               0.231872
# PoorHousing                    0.212722
# StateCare                      0.210972
# Pain                          -0.199250
# MoodProblems                  -0.186754
# dtype: float64
# v_0
# PoorMentalStatus          -0.295855
# DifficultBehavior          0.280469
# Pain                       0.274107
# PositiveSocialSituation   -0.263692
# MaxCare                    0.260737
# BedSores                   0.255052
# PoorCondition              0.244663
# NeedsMovementAssist        0.243499
# bias                       0.240752
# PoorADLs                  -0.221840
# dtype: float64
# v_1
# SubstanceAbuse               -0.340489
# MaxCare                       0.320088
# SchedulingDifficulties        0.304386
# Noshow                       -0.294068
# PoorCompetency                0.256313
# ProblemsFollowingMeds        -0.253578
# TransportationDifficulties   -0.253051
# PoorCondition                -0.236459
# FallRisk                     -0.217666
# PositivePhysical              0.200454
# dtype: float64
# v_2
# FallRisk                   0.419204
# CMP                        0.329456
# MoodProblems              -0.278919
# PoorPhysical               0.266751
# Jail                       0.264478
# SubstanceAbuse            -0.250351
# StateCare                 -0.247499
# FeelsUnsafe                0.239681
# PositiveCognitiveIssues    0.219648
# Noshow                     0.206589
# dtype: float64
# v_3
# ProblemsFollowingMeds         -0.329190
# Noshow                         0.298939
# Pain                          -0.279267
# SchedulingDifficulties         0.275107
# NeedsMovementAssist            0.271121
# HistoryofMultipleAdmissions   -0.250235
# NegativeIdeation               0.246399
# PoorPhysical                  -0.220518
# PoorHousing                   -0.214162
# SubstanceAbuse                 0.214025
# dtype: float64
# v_4
# PoorSocialSupport          0.412760
# bias                       0.332030
# PoorADLs                   0.280873
# MoodProblems               0.259104
# FallRisk                   0.251694
# PositiveSocialSituation    0.251491
# CMP                        0.243550
# PoorHealthLiteracy        -0.208937
# StateCare                  0.174152
# Pain                       0.171787
# dtype: float64
# v_0
# FinancialProblems      -0.352448
# DifficultBehavior       0.343839
# StateCare              -0.326592
# SubstanceAbuse         -0.305971
# PoorCondition           0.276766
# NoHealthCarePlanning   -0.232408
# PoorHousing            -0.225448
# NegativeIdeation       -0.189740
# PoorPhysical           -0.180307
# PoorSocialSupport       0.178866
# dtype: float64
# v_1
# bias                          0.378895
# NegativeIdeation              0.360133
# SchedulingDifficulties        0.315814
# PositiveSocialSituation      -0.243617
# International                 0.238603
# AtRisk                        0.227628
# NoHealthCarePlanning          0.217464
# TransportationDifficulties   -0.206081
# PoorCondition                 0.203446
# PoorMentalStatus              0.195997
# dtype: float64
# v_2
# SubstanceAbuse             0.360435
# ClinicalTroubles           0.349837
# NeedsMovementAssist       -0.315925
# PositiveCognitiveIssues    0.260761
# PositivePhysical           0.234581
# PoorCondition              0.234263
# bias                       0.228996
# NoHealthCarePlanning      -0.215059
# AtRisk                     0.196474
# PoorCompetency             0.185995
# dtype: float64
# v_3
# DomesticAbuse             -0.338591
# NegativeIdeation          -0.333118
# FinancialProblems          0.281884
# BedSores                   0.259880
# Jail                       0.257246
# FeelsUnsafe                0.227869
# StateCare                 -0.207633
# PositiveSocialSituation    0.205299
# SchedulingDifficulties    -0.204380
# SubstanceAbuse            -0.189571
# dtype: float64
# v_4
# PoorHousing            -0.370026
# AtRisk                  0.331534
# NonCompliance          -0.297053
# DifficultBehavior      -0.292624
# NoHealthCarePlanning    0.282602
# PoorADLs                0.269503
# International          -0.243672
# Noshow                 -0.223723
# MoodProblems           -0.210708
# NeedsMovementAssist    -0.200752
# dtype: float64
# cv 1
# v_0
# SubstanceAbuse            -0.452366
# PoorPrognosis             -0.373347
# Pain                       0.310444
# FallRisk                  -0.253263
# DifficultBehavior         -0.253162
# ProblemsFollowingMeds      0.217619
# PoorCompetency             0.212194
# SchedulingDifficulties     0.198905
# PositiveSocialSituation    0.195252
# PoorHealthLiteracy        -0.178555
# dtype: float64
# v_1
# AtRisk                         0.350752
# PositiveSocialSituation       -0.326391
# BedSores                       0.306054
# StateCare                     -0.296912
# PositiveCognitiveIssues       -0.244981
# NegativeIdeation               0.236117
# TransportationDifficulties     0.229640
# PoorCondition                  0.222351
# International                  0.200551
# HistoryofMultipleAdmissions   -0.198952
# dtype: float64
# v_2
# MoodProblems             -0.441337
# MaxCare                  -0.298875
# bias                      0.295183
# PoorPhysical             -0.272748
# PoorCondition             0.271497
# PoorMentalStatus          0.237877
# NoHealthCarePlanning     -0.233352
# SchedulingDifficulties    0.210558
# SubstanceAbuse            0.203710
# FinancialProblems         0.198243
# dtype: float64
# v_3
# bias                    0.400745
# CMP                     0.379170
# NoHealthCarePlanning    0.298095
# MoodProblems            0.291459
# NeedsMovementAssist     0.282427
# International           0.278686
# PoorMentalStatus        0.247582
# DifficultBehavior       0.213451
# SubstanceAbuse          0.212207
# StateCare               0.192341
# dtype: float64
# v_4
# PositiveCognitiveIssues    0.346679
# PoorADLs                   0.336394
# PoorSocialSupport         -0.311687
# FallRisk                   0.301951
# PoorHealthLiteracy         0.292400
# Noshow                    -0.235805
# NeedsMovementAssist        0.229536
# MoodProblems              -0.203283
# CMP                        0.197063
# NonCompliance             -0.180709
# dtype: float64
# v_0
# DifficultBehavior              0.352244
# StateCare                      0.349722
# PoorPrognosis                 -0.307621
# CMP                           -0.250935
# HistoryofMultipleAdmissions   -0.235797
# PositiveSocialSituation        0.230890
# FallRisk                       0.229545
# PoorMentalStatus               0.228272
# SubstanceAbuse                 0.211477
# DomesticAbuse                  0.190648
# dtype: float64
# v_1
# NoHealthCarePlanning   -0.305244
# NegativeIdeation        0.282311
# MoodProblems            0.281034
# International           0.274167
# SubstanceAbuse         -0.240394
# PoorCompetency         -0.236831
# PoorPhysical           -0.228019
# StateCare              -0.226395
# DomesticAbuse          -0.211565
# AtRisk                 -0.207420
# dtype: float64
# v_2
# ClinicalTroubles               0.402277
# NegativeIdeation               0.285276
# SchedulingDifficulties        -0.276419
# International                  0.264580
# Pain                          -0.263883
# PoorADLs                      -0.263240
# NeedsMovementAssist           -0.232569
# HistoryofMultipleAdmissions    0.205643
# BedSores                       0.198430
# PoorPhysical                   0.198416
# dtype: float64
# v_3
# MoodProblems                   0.404168
# DomesticAbuse                  0.355742
# Noshow                         0.284051
# PositivePhysical               0.254695
# bias                           0.246531
# CMP                            0.241022
# PoorMentalStatus               0.233425
# PoorPrognosis                  0.212882
# ClinicalTroubles               0.204274
# HistoryofMultipleAdmissions    0.200037
# dtype: float64
# v_4
# ClinicalTroubles               0.367067
# NoHealthCarePlanning           0.355783
# DomesticAbuse                 -0.348987
# SchedulingDifficulties         0.267507
# CMP                            0.236149
# NeedsMovementAssist            0.233550
# PositiveSocialSituation        0.223001
# HistoryofMultipleAdmissions    0.218792
# ProblemsFollowingMeds          0.196512
# FallRisk                       0.195812
# dtype: float64
# v_0
# PositiveSocialSituation        0.374021
# ClinicalTroubles              -0.334840
# PoorPhysical                   0.278185
# Jail                          -0.272838
# HistoryofMultipleAdmissions   -0.234829
# MoodProblems                   0.231831
# StateCare                     -0.230953
# FeelsUnsafe                    0.214739
# FallRisk                      -0.204624
# DifficultBehavior             -0.170541
# dtype: float64
# v_1
# PositivePhysical           0.315642
# PoorCondition              0.288148
# PoorPhysical               0.284073
# CMP                        0.265963
# NoHealthCarePlanning      -0.235978
# NeedsMovementAssist        0.223897
# PoorHousing               -0.220005
# SubstanceAbuse            -0.218862
# MoodProblems               0.216404
# PositiveCognitiveIssues    0.211570
# dtype: float64
# v_2
# AtRisk                         0.321266
# PoorMentalStatus               0.315313
# HistoryofMultipleAdmissions   -0.314018
# bias                           0.313178
# MaxCare                        0.286500
# FallRisk                       0.256857
# PoorADLs                       0.225936
# PoorPrognosis                 -0.225854
# ClinicalTroubles              -0.199458
# SubstanceAbuse                -0.189137
# dtype: float64
# v_3
# NoHealthCarePlanning         -0.360177
# PoorSocialSupport             0.346015
# DifficultBehavior             0.301565
# PoorMentalStatus              0.298075
# NeedsMovementAssist           0.297295
# FeelsUnsafe                  -0.270227
# NonCompliance                 0.245232
# PositiveSocialSituation       0.228963
# SchedulingDifficulties        0.202003
# TransportationDifficulties   -0.171941
# dtype: float64
# v_4
# bias                          0.425672
# PoorADLs                     -0.334620
# PoorSocialSupport             0.308419
# TransportationDifficulties    0.293225
# MoodProblems                  0.282297
# NegativeIdeation             -0.228509
# PositivePhysical             -0.216275
# NonCompliance                -0.191126
# ProblemsFollowingMeds         0.186358
# PositiveCognitiveIssues       0.183256
# dtype: float64
# cv 2
# v_0
# PositivePhysical          0.405484
# PoorCondition            -0.339747
# PoorPhysical              0.309806
# bias                      0.297294
# SchedulingDifficulties   -0.265055
# NoHealthCarePlanning     -0.241886
# PoorADLs                 -0.237841
# Pain                     -0.230832
# PoorMentalStatus          0.203262
# PoorHousing               0.197288
# dtype: float64
# v_1
# BedSores            0.342074
# PoorMentalStatus   -0.326356
# Noshow             -0.324111
# PoorPrognosis      -0.284402
# bias               -0.277473
# DomesticAbuse      -0.276881
# Pain               -0.222749
# SubstanceAbuse      0.209733
# ClinicalTroubles   -0.190960
# NonCompliance       0.179021
# dtype: float64
# v_2
# PoorHealthLiteracy    0.387392
# MoodProblems          0.359727
# bias                 -0.295434
# DifficultBehavior     0.295173
# CMP                   0.263121
# PoorMentalStatus      0.262023
# StateCare            -0.242301
# Pain                 -0.225790
# ClinicalTroubles     -0.203497
# FinancialProblems     0.178380
# dtype: float64
# v_3
# StateCare                      0.339402
# PositiveCognitiveIssues       -0.330538
# FinancialProblems              0.288124
# PoorSocialSupport              0.284725
# PoorHousing                    0.269883
# AtRisk                         0.244738
# HistoryofMultipleAdmissions    0.240966
# BedSores                      -0.233884
# CMP                            0.222380
# FeelsUnsafe                   -0.206298
# dtype: float64
# v_4
# NeedsMovementAssist           0.435264
# SchedulingDifficulties       -0.325459
# PoorPhysical                 -0.276598
# PoorMentalStatus              0.263163
# CMP                          -0.231013
# PoorSocialSupport             0.221589
# BedSores                      0.218831
# TransportationDifficulties   -0.218095
# ProblemsFollowingMeds        -0.205283
# International                 0.184790
# dtype: float64
# v_0
# NonCompliance              0.417716
# PositiveSocialSituation    0.330497
# DifficultBehavior          0.284170
# PoorCompetency             0.266438
# DomesticAbuse             -0.244681
# AtRisk                     0.214128
# bias                      -0.204027
# FinancialProblems         -0.191319
# ClinicalTroubles          -0.190743
# BedSores                   0.176520
# dtype: float64
# v_1
# Jail                           0.451824
# NeedsMovementAssist           -0.264548
# MaxCare                       -0.264242
# FeelsUnsafe                   -0.256674
# FallRisk                      -0.254613
# HistoryofMultipleAdmissions    0.242767
# PositiveSocialSituation       -0.238953
# PoorPrognosis                 -0.230109
# SubstanceAbuse                -0.228399
# Pain                          -0.214954
# dtype: float64
# v_2
# AtRisk                -0.371153
# PoorSocialSupport      0.307302
# CMP                   -0.303990
# PoorCondition         -0.292446
# NeedsMovementAssist    0.267959
# MoodProblems          -0.261764
# bias                  -0.243437
# PoorCompetency         0.242339
# SubstanceAbuse        -0.230266
# StateCare              0.199778
# dtype: float64
# v_3
# PoorADLs                  0.388956
# Pain                      0.332048
# PoorPhysical             -0.317381
# SchedulingDifficulties   -0.265856
# NeedsMovementAssist      -0.252447
# PoorHealthLiteracy       -0.223936
# SubstanceAbuse            0.217220
# FallRisk                 -0.214650
# PoorSocialSupport         0.203284
# ProblemsFollowingMeds     0.194643
# dtype: float64
# v_4
# Noshow                 0.509702
# PoorMentalStatus       0.305615
# International          0.303569
# DomesticAbuse          0.295471
# StateCare              0.258367
# NeedsMovementAssist    0.217915
# bias                   0.194038
# DifficultBehavior      0.192890
# Pain                   0.183229
# CMP                    0.173110
# dtype: float64
# v_0
# FeelsUnsafe                   -0.391994
# DifficultBehavior             -0.348912
# PositiveCognitiveIssues        0.301430
# PoorHousing                    0.294697
# PoorHealthLiteracy            -0.282174
# CMP                           -0.265521
# StateCare                      0.256928
# HistoryofMultipleAdmissions    0.246224
# MaxCare                       -0.193116
# International                 -0.161605
# dtype: float64
# v_1
# PoorCondition            -0.345091
# Pain                     -0.306687
# PoorHousing              -0.294550
# PoorMentalStatus          0.284671
# MoodProblems             -0.252524
# NeedsMovementAssist       0.251855
# DomesticAbuse            -0.246858
# PoorCompetency           -0.227755
# SchedulingDifficulties   -0.226961
# Noshow                   -0.212200
# dtype: float64
# v_2
# AtRisk                    -0.397585
# International             -0.282972
# SchedulingDifficulties     0.252594
# PositiveCognitiveIssues   -0.234042
# CMP                        0.230600
# FinancialProblems          0.228806
# PoorMentalStatus          -0.220725
# FallRisk                  -0.198523
# PositivePhysical          -0.197113
# ProblemsFollowingMeds      0.193142
# dtype: float64
# v_3
# SubstanceAbuse                 0.439208
# MoodProblems                   0.436390
# Noshow                         0.305746
# DomesticAbuse                 -0.277753
# NeedsMovementAssist            0.265079
# ProblemsFollowingMeds          0.239644
# PoorCondition                 -0.204627
# NoHealthCarePlanning          -0.183432
# HistoryofMultipleAdmissions   -0.178320
# AtRisk                        -0.171751
# dtype: float64
# v_4
# ClinicalTroubles             -0.431391
# PoorPhysical                  0.338983
# PoorSocialSupport             0.254884
# ProblemsFollowingMeds        -0.239439
# StateCare                    -0.238731
# PoorPrognosis                -0.211344
# PositivePhysical              0.204618
# International                 0.192818
# DomesticAbuse                -0.189519
# TransportationDifficulties    0.183355
# dtype: float64
# cv 3
# v_0
# PoorMentalStatus           0.405215
# PoorHealthLiteracy         0.376516
# bias                       0.339459
# CMP                        0.245137
# ClinicalTroubles           0.243780
# DifficultBehavior         -0.228976
# BedSores                   0.215031
# PositiveCognitiveIssues   -0.191179
# PositiveSocialSituation   -0.184972
# PoorADLs                   0.171926
# dtype: float64
# v_1
# PoorCompetency             0.315573
# DomesticAbuse             -0.293231
# ClinicalTroubles          -0.292959
# NegativeIdeation           0.287993
# AtRisk                     0.279318
# PositiveCognitiveIssues    0.244994
# PoorPhysical              -0.213441
# Jail                      -0.211440
# NoHealthCarePlanning       0.187521
# PoorHealthLiteracy        -0.185705
# dtype: float64
# v_2
# MoodProblems              -0.308752
# SchedulingDifficulties    -0.294719
# Noshow                    -0.291412
# ClinicalTroubles          -0.273040
# PoorCompetency             0.238998
# PositiveCognitiveIssues   -0.230585
# MaxCare                    0.221476
# FallRisk                  -0.211464
# International             -0.209471
# PoorMentalStatus          -0.193171
# dtype: float64
# v_3
# PoorCompetency            -0.398373
# DomesticAbuse             -0.396296
# bias                      -0.358190
# NeedsMovementAssist        0.323724
# International             -0.249115
# PoorHealthLiteracy         0.226244
# PositiveCognitiveIssues    0.186549
# Pain                       0.183445
# PoorMentalStatus           0.179919
# FeelsUnsafe                0.179339
# dtype: float64
# v_4
# PoorPhysical                  -0.342264
# International                 -0.308580
# NonCompliance                  0.307250
# PoorADLs                       0.270651
# DifficultBehavior              0.258506
# HistoryofMultipleAdmissions   -0.254657
# NegativeIdeation               0.233978
# FallRisk                       0.225736
# Jail                           0.204485
# Pain                           0.176816
# dtype: float64
# v_0
# FinancialProblems     0.363970
# StateCare             0.343631
# PoorADLs             -0.340578
# NonCompliance        -0.283121
# PositivePhysical     -0.276014
# PoorHealthLiteracy   -0.246582
# PoorHousing           0.237716
# bias                 -0.227517
# Jail                  0.189163
# SubstanceAbuse       -0.182693
# dtype: float64
# v_1
# FallRisk                  0.494606
# BedSores                  0.310318
# Jail                     -0.287947
# Pain                     -0.250590
# PoorMentalStatus          0.214176
# PoorCompetency            0.206018
# Noshow                    0.195040
# SubstanceAbuse           -0.192590
# ClinicalTroubles          0.186133
# SchedulingDifficulties   -0.181744
# dtype: float64
# v_2
# NeedsMovementAssist          -0.406071
# TransportationDifficulties   -0.394079
# FinancialProblems            -0.265022
# PoorSocialSupport            -0.242142
# FallRisk                      0.237778
# PoorMentalStatus             -0.224088
# International                 0.205792
# NonCompliance                 0.190946
# DifficultBehavior            -0.184580
# PoorCondition                 0.168133
# dtype: float64
# v_3
# PoorCondition                -0.453678
# Jail                          0.321058
# PoorSocialSupport             0.305882
# FallRisk                      0.245121
# ProblemsFollowingMeds         0.219443
# FinancialProblems             0.215117
# DifficultBehavior            -0.209436
# NegativeIdeation             -0.202314
# PoorADLs                      0.193178
# TransportationDifficulties   -0.188425
# dtype: float64
# v_4
# DomesticAbuse             0.362420
# bias                      0.265676
# NonCompliance            -0.253285
# SchedulingDifficulties    0.251825
# DifficultBehavior        -0.239816
# FeelsUnsafe              -0.229455
# PoorPhysical              0.215798
# FallRisk                  0.214543
# Noshow                    0.211534
# ProblemsFollowingMeds     0.210811
# dtype: float64
# v_0
# AtRisk                    -0.329828
# StateCare                 -0.326741
# PositiveSocialSituation    0.299072
# NoHealthCarePlanning      -0.271647
# FallRisk                  -0.268333
# PoorMentalStatus           0.237393
# PoorADLs                  -0.233267
# PoorHousing               -0.230434
# PoorSocialSupport         -0.224911
# MoodProblems               0.215135
# dtype: float64
# v_1
# PositivePhysical   -0.384300
# Noshow             -0.339948
# PoorCondition      -0.317418
# CMP                -0.280068
# PoorCompetency     -0.268838
# AtRisk             -0.247177
# PoorMentalStatus   -0.227904
# ClinicalTroubles   -0.214119
# MaxCare            -0.198475
# NonCompliance      -0.185077
# dtype: float64
# v_2
# DomesticAbuse            -0.394688
# PoorPhysical              0.301011
# NeedsMovementAssist       0.277384
# ProblemsFollowingMeds    -0.268604
# Pain                     -0.249004
# ClinicalTroubles          0.235947
# DifficultBehavior        -0.230669
# SchedulingDifficulties   -0.229912
# PoorPrognosis            -0.199046
# PoorSocialSupport        -0.191879
# dtype: float64
# v_3
# bias                   -0.378694
# Noshow                  0.332409
# PoorHousing             0.317401
# PoorMentalStatus       -0.311967
# ClinicalTroubles       -0.303792
# PoorADLs               -0.279607
# International           0.226723
# PoorSocialSupport      -0.223070
# NoHealthCarePlanning    0.208332
# PoorHealthLiteracy      0.187079
# dtype: float64
# v_4
# PoorHousing              0.334915
# Jail                    -0.304443
# PoorHealthLiteracy       0.302070
# ProblemsFollowingMeds    0.249098
# NoHealthCarePlanning     0.246329
# International           -0.229077
# PoorPrognosis            0.214510
# PoorCondition           -0.214279
# Noshow                   0.207680
# PoorMentalStatus         0.200135
# dtype: float64
# cv 4
# v_0
# PoorSocialSupport             0.394848
# bias                         -0.294252
# FallRisk                      0.256425
# TransportationDifficulties    0.254215
# SubstanceAbuse               -0.241537
# AtRisk                        0.228845
# MaxCare                      -0.217566
# PoorHousing                   0.212370
# PositiveSocialSituation      -0.201789
# DifficultBehavior            -0.200398
# dtype: float64
# v_1
# FallRisk                       0.431809
# PositiveSocialSituation       -0.412656
# PoorMentalStatus               0.369048
# PositivePhysical               0.311488
# NeedsMovementAssist            0.206490
# FinancialProblems              0.198341
# DomesticAbuse                  0.198012
# HistoryofMultipleAdmissions    0.191507
# ProblemsFollowingMeds         -0.145272
# PoorHealthLiteracy            -0.134299
# dtype: float64
# v_2
# PositivePhysical      -0.385721
# PoorADLs               0.354335
# BedSores               0.325548
# DomesticAbuse          0.319125
# MaxCare                0.263834
# NeedsMovementAssist    0.210638
# NegativeIdeation      -0.202326
# FeelsUnsafe            0.189385
# StateCare             -0.187309
# DifficultBehavior      0.184411
# dtype: float64
# v_3
# NeedsMovementAssist       -0.555049
# PoorSocialSupport         -0.401866
# StateCare                  0.296857
# PositiveSocialSituation   -0.284387
# SubstanceAbuse            -0.239794
# MoodProblems              -0.198324
# PoorCondition              0.190996
# NoHealthCarePlanning      -0.167822
# ProblemsFollowingMeds      0.166351
# Pain                      -0.157617
# dtype: float64
# v_4
# PoorSocialSupport          0.294915
# SubstanceAbuse            -0.290643
# bias                       0.275645
# PoorPrognosis              0.260369
# NonCompliance              0.253370
# PositiveSocialSituation    0.251693
# DifficultBehavior          0.238503
# Pain                      -0.237017
# Noshow                    -0.209604
# PoorMentalStatus           0.207681
# dtype: float64
# v_0
# Noshow                         0.346344
# PoorCondition                  0.334021
# ClinicalTroubles               0.307943
# HistoryofMultipleAdmissions    0.264332
# Pain                          -0.260266
# TransportationDifficulties     0.248001
# PoorHousing                   -0.232021
# DomesticAbuse                  0.213196
# AtRisk                         0.206508
# PositiveCognitiveIssues        0.195559
# dtype: float64
# v_1
# MoodProblems                  -0.480218
# SubstanceAbuse                 0.350474
# PositiveCognitiveIssues        0.256267
# Jail                           0.252259
# MaxCare                       -0.221033
# DifficultBehavior              0.215473
# bias                           0.207808
# CMP                            0.206402
# HistoryofMultipleAdmissions   -0.204502
# PoorCondition                  0.201633
# dtype: float64
# v_2
# MaxCare                      -0.369018
# DifficultBehavior            -0.304115
# PositiveSocialSituation       0.298240
# TransportationDifficulties    0.287486
# PoorPhysical                 -0.286334
# Pain                          0.233808
# AtRisk                        0.231672
# NoHealthCarePlanning         -0.215307
# PoorMentalStatus             -0.196023
# PoorCompetency               -0.194637
# dtype: float64
# v_3
# BedSores                     -0.424842
# PoorHealthLiteracy            0.351468
# FallRisk                     -0.309266
# PoorMentalStatus              0.270684
# PoorPhysical                  0.245713
# PoorADLs                     -0.238761
# MoodProblems                 -0.186241
# PositiveCognitiveIssues      -0.170914
# TransportationDifficulties    0.169755
# PositiveSocialSituation       0.164122
# dtype: float64
# v_4
# DifficultBehavior    0.354748
# PoorMentalStatus     0.336093
# Noshow               0.320782
# MoodProblems         0.275861
# FinancialProblems   -0.250113
# FeelsUnsafe          0.245874
# PoorCompetency       0.218486
# BedSores            -0.180472
# AtRisk              -0.180390
# PoorSocialSupport    0.176578
# dtype: float64
# v_0
# PoorPrognosis              0.385409
# DifficultBehavior          0.370678
# FinancialProblems          0.310178
# FallRisk                   0.247483
# MoodProblems              -0.244504
# PositiveSocialSituation    0.226089
# PoorCondition              0.224330
# PositivePhysical          -0.206887
# Noshow                    -0.193543
# PoorSocialSupport          0.176427
# dtype: float64
# v_1
# Noshow                     0.472544
# NeedsMovementAssist        0.405067
# PoorMentalStatus           0.399001
# MoodProblems               0.294075
# bias                       0.258143
# AtRisk                     0.238808
# PositiveCognitiveIssues   -0.180006
# PoorSocialSupport          0.146013
# ClinicalTroubles           0.138113
# SchedulingDifficulties    -0.133911
# dtype: float64
# v_2
# AtRisk                        0.396370
# SubstanceAbuse               -0.390482
# TransportationDifficulties    0.309187
# BedSores                      0.266922
# PositiveSocialSituation       0.250410
# NonCompliance                -0.243116
# PositiveCognitiveIssues       0.217323
# Pain                          0.203699
# PoorPrognosis                -0.179163
# Jail                         -0.168405
# dtype: float64
# v_3
# MaxCare                   0.367145
# FallRisk                 -0.295487
# ClinicalTroubles          0.294064
# SchedulingDifficulties   -0.278142
# PositivePhysical         -0.234743
# PoorPhysical              0.218844
# NeedsMovementAssist      -0.208906
# PoorCondition            -0.204223
# AtRisk                   -0.193185
# FinancialProblems         0.189418
# dtype: float64
# v_4
# PoorMentalStatus    -0.473225
# PoorSocialSupport   -0.361094
# FeelsUnsafe          0.264559
# ClinicalTroubles     0.247981
# PoorPhysical         0.239115
# MoodProblems         0.231002
# MaxCare             -0.207241
# PoorPrognosis        0.193772
# NegativeIdeation    -0.180021
# PoorCompetency      -0.177939
# dtype: float64
# 0    0.689734
# 1    0.620128
# 2    0.546620
# 3    0.704262
# 4    0.591474
# dtype: float64 mean: 0.630443381374 std: 0.0593563998627
