# %%
import constants
cache_folder_name = 'ratio=logreg;loss=squared;method=pymanopt_UB'
seed = 44

# %%
import autograd.numpy as np
np.random.seed(seed)
import python_utils.python_utils.basic as basic
import python_utils.python_utils.caching as caching
log_folder = '%s/%s' % (constants.cache_folder, cache_folder_name)
caching.init(constants.cache_folder, constants.which_hash, basic.archiver(log_folder))
# %load_ext autoreload
# %autoreload 2
import matplotlib
matplotlib.use('Agg')
# Out:
# [Errno 17] File exists: '/Users/fultonw/Documents/projects/runs/domain_adapt_run/domain_adapt_run/notebooks/new/hyperparameter_loss_surface_stratified/boston_housing/cache/ratio=logreg;loss=squared;method=pymanopt_UB'

# %%
import matplotlib.pyplot as plt
from IPython.display import display_pretty, display_html
import python_utils.python_utils.basic as basic
import pandas as pd
import pdb
import itertools
import functools
import scipy.stats
import scipy
import cvxopt
import autograd
import autograd.numpy as np
import domain_adapt.domain_adapt.new.fxns as fxns
import domain_adapt.domain_adapt.new.utils as utils
import domain_adapt.domain_adapt.new.optimizers as optimizers
import domain_adapt.domain_adapt.new.constructors as constructors
#import domain_adapt.domain_adapt.SDR_data as data
import domain_adapt_run.domain_adapt_run.notebooks.new.hyperparameter_loss_surface_stratified.run as run
import data.domain_adapt_data.domain_adapt_data.fxns as data
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
# define data
training_proportion = 0.65
training_sampler = functools.partial(data.doubly_robust_paper_pca_subsample, 0.3)
get_data_f = data.boston_housing
num_data = 350

# %%
#
get_data = functools.partial(data.get_data_helper, training_proportion, training_sampler, get_data_f, num_data)

# %%
# test get_data
xs_train, ys_train, xs_test, ys_test = get_data(1)
print 'xs_train shape:', xs_train.shape, 'xs_test_shape', xs_test.shape
# Out:
# ('seed: 1',)
# ('original_xs: (320, 13), original_ys_shape: (320,)',)
# ('original_xs_train: (204, 13) original_ys_train: (204,)',)
# ('original_xs_test: (116, 13) original_ys_test: (116,)',)
# ('sampled_xs_train: (102, 13) sampled_ys_train: (102,)',)
# xs_train shape: (102, 13) xs_test_shape (102,)

# %%
# define fitter
pymanopt_options={'logverbosity':2, 'maxiter':100}
#u_dim = 1
unconstrained = False
num_tries = 5
plot_b_info = constructors.plot_b_info
def get_fitter(c_lsqr_loss, c_lsqr_loss_eval, c_lsqr, c_logreg, weight_reg, UB_reg, sigma, max_ratio, u_dim):
    B_init_f_getter = lambda xs_train, ys_train, xs_test: (lambda: np.random.normal(size=(xs_train.shape[1],u_dim)))
    return constructors.logreg_ratio_UB_fitter(c_lsqr, c_logreg, weight_reg, UB_reg, sigma, B_init_f_getter, unconstrained, c_lsqr_loss, c_lsqr_loss_eval, max_ratio=max_ratio, num_tries=num_tries, pymanopt_options=pymanopt_options, plot_b_info=plot_b_info)

# %%
# define hyperparameter search space via an iterator
UB_regs = [0.]#1,1.,10.]
u_dims = [1,]
c_lsqr_losses = [1.]
c_lsqr_loss_evals = [0.]
c_lsqrs = [.1,1.,10.,100]
c_logregs = [0.1,1.,10.]
weight_regs = [0.1,1.,10.]
sigmas = [0.25,1.,5.]#,5.]
max_ratios = [5.]
make_tuple = lambda key, vals: [(key,val) for val in vals]
care_hyperparam_tuples = itertools.product(
    make_tuple('UB_reg',UB_regs), 
    make_tuple('u_dim',u_dims), 
    )
nocare_hyperparam_tuples = itertools.product(
    make_tuple('c_lsqr_loss',c_lsqr_losses), 
    make_tuple('c_lsqr_loss_eval',c_lsqr_loss_evals), 
    make_tuple('c_lsqr',c_lsqrs), 
    make_tuple('c_logreg',c_logregs), 
    make_tuple('weight_reg',weight_regs), 
    make_tuple('UB_reg',UB_regs), 
    make_tuple('sigma',sigmas), 
    make_tuple('max_ratio',max_ratios)
    )

# %%
# define mapper
mapper = map

# %%
#
num_iterations = 3

# %%
# 
run.run(get_data, get_fitter, care_hyperparam_tuples, nocare_hyperparam_tuples, num_iterations, mapper)
# Out:
# ('seed: 0',)
# ('original_xs: (320, 13), original_ys_shape: (320,)',)
# ('original_xs_train: (208, 13) original_ys_train: (208,)',)
# ('original_xs_test: (112, 13) original_ys_test: (112,)',)
# ('sampled_xs_train: (90, 13) sampled_ys_train: (90,)',)
#  iter		   cost val	    grad. norm
#     1	+7.4924158117877567e+04	1.26606619e+05
#     2	+6.8731117607382359e+04	2.57005072e+05
#     3	+6.5471779325526732e+04	8.51021625e+04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8844ff4d8453> in <module>()
#       1 #
# ----> 2 run.run(get_data, get_fitter, care_hyperparam_tuples, nocare_hyperparam_tuples, num_iterations, mapper)
#
# /Users/fultonw/Documents/projects/runs/domain_adapt_run/domain_adapt_run/notebooks/new/hyperparameter_loss_surface_stratified/run.pyc in run(get_data, get_fitter, care_hyperparam_tupless, nocare_hyperparam_tupless, num_iterations, mapper)
#      32     for care_hyperparam_tuples in care_hyperparam_tupless:
#      33         this_hyperparam_tupless = [care_hyperparam_tuples + nocare_hyperparam_tuples for nocare_hyperparam_tuples in nocare_hyperparam_tupless]
# ---> 34         this_results = mapper(horse, this_hyperparam_tupless)
#      35         this_results_display = ['%s: mean_loss(std_loss): %.2f(%.2f)' % (hyperparam_tuples, result_dict['mean_loss'], result_dict['std_loss']) for (hyperparam_tuples, result_dict) in this_results]
#      36         best_hyperparam_tuples, best_result_dict = min(this_results, key=lambda (hyperparam_tuples,result_dict): result_dict['mean_loss'])
#
# /Users/fultonw/Documents/projects/runs/domain_adapt_run/domain_adapt_run/notebooks/new/hyperparameter_loss_surface_stratified/run.pyc in horse_helper(get_data, get_fitter, num_iterations, hyperparam_tuples)
#      16     for i in xrange(num_iterations):
#      17         xs_train, xs_test, ys_train, ys_test = get_data(seed=i)
# ---> 18         predictor = fitter(xs_train, xs_test, ys_train, ys_test)
#      19         ys_test_hat = predictor(xs_test)
#      20         test_errors = ys_test - ys_test_hat
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/constructors.pyc in fitter(xs_train, xs_test, ys_train, ys_test)
#     244         B_init_f = B_init_f_getter(xs_train, ys_train, xs_test)
#     245
# --> 246         B_fit = optimizer.optimize(objective, dobjective_dB, B_init_f)
#     247
#     248         logreg_ratios_fxn = fxns.two_step( # xs_train, xs_test, sigma, B, c_logreg, scale_sigma, max_ratio
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/optimizers.pyc in optimize(self, *args)
#     162         for i in xrange(self.num_tries):
#     163             init_vals = tuple([init_f() for init_f in init_fs])
# --> 164             x = self.horse.optimize(*(opt_args+init_vals))
#     165             xs.append(x)
#     166             opt_logs.append(self.horse.opt_log)
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/optimizers.pyc in optimize(self, objective, dobjective_dB, B_init)
#      19         from pymanopt import Problem
#      20         problem = pymanopt.Problem(manifold=manifold, cost=objective, egrad=dobjective_dB, verbosity=2)
# ---> 21         B_fit, self.opt_log = solver.solve(problem, x=B_init)
#      22         return B_fit
#      23
#
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pymanopt/solvers/steepest_descent.pyc in solve(self, problem, x, reuselinesearch)
#      73             # Calculate new cost, grad and gradnorm
#      74             cost = objective(x)
# ---> 75             grad = gradient(x)
#      76             gradnorm = man.norm(x, grad)
#      77             iter = iter + 1
#
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pymanopt/core/problem.pyc in grad(x)
#     122
#     123             def grad(x):
# --> 124                 return self.manifold.egrad2rgrad(x, egrad(x))
#     125             self._grad = grad
#     126         return self._grad
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/constructors.pyc in <lambda>(B)
#     230
#     231         objective = lambda B: final_fxn.val(ys_train, xs_train, xs_test, ws_full_train, sigma, B, c_lsqr_loss, c_lsqr_loss_eval, c_lsqr, c_logreg, scale_sigma, max_ratio)
# --> 232         dobjective_dB = lambda B: final_fxn.grad(ys_train, xs_train, xs_test, ws_full_train, sigma, B, c_lsqr_loss, c_lsqr_loss_eval, c_lsqr, c_logreg, scale_sigma, max_ratio, care_argnums=(5,))
#     233
#     234         if unconstrained:
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/fxns.pyc in grad(self, *args, **kwargs)
#      88             pass
#      89         try:
# ---> 90             val, grad = self._val_and_grad(*args, care_argnums=care_argnums)
#      91             return grad
#      92         except NotImplementedError:
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/fxns.pyc in _val_and_grad(self, *args, **kwargs)
#      46
#      47     def _val_and_grad(self, *args, **kwargs):
# ---> 48         return self._val_and_grad_default(*args, **kwargs)
#      49
#      50     def _val_and_grad_default(self, *args, **kwargs):
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/fxns.pyc in _val_and_grad_default(self, *args, **kwargs)
#      55         try:
#      56             temps, val = self.forward_prop(*args)
# ---> 57             grad = self.backward_prop(args, temps, val, care_argnums)
#      58             return val, grad
#      59         except NotImplementedError:
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/fxns.pyc in backward_prop(self, args, (g_val,), h_val, care_argnums)
#     680         self.check_care_argnums(args, care_argnums) # special
#     681         p = args[care_argnums[0]]
# --> 682         dh_dg_dg_dp_val = self.two_step_grad(args, (g_val,), h_val, care_argnums)
#     683 #        pdb.set_trace()
#     684         if care_argnums[0] in self.h_argnums:
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/fxns.pyc in two_step_grad(self, args, (g_val,), h_val, care_argnums)
#     732             h_args = self.h_args(g_val, *args)
#     733     #        d_dp_df_dx_val = self.full_quad_opt.dobjective_dx.grad(*(quad_args+(x_opt,)), care_argnums=(len(quad_args)-1,))
# --> 734             d_dp_df_dx_val = self.g.dobjective_dx.grad(*(g_args+(g_val,)), care_argnums=(care_argnum_in_g_args,))
#     735             dh_dxopt_val = self.h.grad(*h_args, care_argnums=(self.g_val_h_argnum,)) # hard
#     736             d_dx_df_dx_val = self.g.dobjective_dx.grad(*(g_args+(g_val,)), care_argnums=(len(g_args),)) # hard
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/fxns.pyc in grad(self, *args, **kwargs)
#      84         self.check_care_argnums(args, care_argnums)
#      85         try:
# ---> 86             return self._grad(*args, care_argnums=care_argnums)
#      87         except NotImplementedError:
#      88             pass
#
# /Users/fultonw/Documents/projects/code/domain_adapt/domain_adapt/new/fxns.pyc in grad(*args, **kwargs)
#     180         nocare_args = [args[i] for i in xrange(len(args)) if not (i in care_argnums)]
#     181 #        pdb.set_trace()
# --> 182         ans = autograd.jacobian(horse)(care_args, nocare_args)
#     183 #        ans = autograd.grad(horse)(care_args, nocare_args)
#     184         return ans
#
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/autograd/convenience_wrappers.pyc in jacfun(*args, **kwargs)
#      35         start_node, end_nodes, tape = forward_pass(list_fun, args, kwargs, argnum)
#      36         run = partial(backward_pass, start_node, tape=tape, preserve_tape=True)
# ---> 37         grads = [run(end_node) for end_node in end_nodes]
#      38         del tape[:]
#      39         shape = dummy.outshape + getshape(args[argnum])
#
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/autograd/core.pyc in backward_pass(start_node, end_node, tape, preserve_tape)
#      57                 "Types are {0} and {1}".format(type(new_node(getval(cur_outgrad))), node.node_type)
#      58             for gradfun, parent in node.parent_grad_ops:
# ---> 59                 og = cast_to_node_type(gradfun(cur_outgrad), parent.node_type, parent.node_value)
#      60                 parent.outgrads.append(og)
#      61
#
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/autograd/numpy/numpy_grads.pyc in gradfun(g)
#     403
#     404         Y_axes_ignored = [i for i in range(anp.ndim(Y)) if i not in Y_axes_summed]
# --> 405         result = anp.tensordot(g, Y, axes=[g_axes_from_Y, Y_axes_ignored])
#     406         sorted_axes_pairs = sorted(zip(X_axes_summed, Y_axes_summed), key = lambda x : x[1])
#     407         forward_permutation = ([i for i in range(anp.ndim(X)) if i not in X_axes_summed]
#
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/autograd/core.pyc in __call__(self, *args, **kwargs)
#     132                         tapes.add(tape)
#     133
# --> 134         result = self.fun(*argvals, **kwargs)
#     135         if result is NotImplemented: return result
#     136         if ops:
#
# /Users/fultonw/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/core/numeric.pyc in tensordot(a, b, axes)
#    1337     at = a.transpose(newaxes_a).reshape(newshape_a)
#    1338     bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1339     res = dot(at, bt)
#    1340     return res.reshape(olda + oldb)
#    1341
#
# KeyboardInterrupt:
